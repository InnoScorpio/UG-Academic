# %%
import csv
from numpy import genfromtxt
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("student.csv")
data
# Out:
#                           School Name  \
# 0            ACE TECHNICAL CHARTER HS
# 1                        AIR FORCE HS
# 2                           ALCOTT HS
# 3                         AMUNDSEN HS
# 4      ASPIRA CHTR - EARLY COLLEGE HS
# 5            ASPIRA CHTR - RAMIREZ HS
# 6               AUSTIN BUS & ENTRP HS
# 7                      AUSTIN POLY HS
# 8             BANNER ACADEMY SOUTH HS
# 9              BANNER ACADEMY WEST HS
# 10                    BANNER NORTH HS
# 11                           BOGAN HS
# 12                           BOWEN HS
# 13                     BRONZEVILLE HS
# 14                          BROOKS HS
# 15                    CARVER MILITARY
# 16                       CHGO ACAD HS
# 17                        CHGO AGR HS
# 18                 CHGO ARTS CONTR HS
# 19     CHGO MATH & SCI ACAD CAMPUS HS
# 20              CHGO MILITARY ACAD HS
# 21                CHGO TALENT CHTR HS
# 22                      CHICAGO AA HS
# ...

# %%
rangea = pd.read_csv('student.csv', usecols=[2, 3, 4]) #1. What does the data tell you. Sum of data.
rtempa = rangea.sum(skipna=True, numeric_only=True)
rtempa
# Out:
# DO2010    1118.1
# DO2011    1076.9
# DO2012    1293.5
# dtype: float64

# %%
rtempb = rangea.mean(skipna=True, numeric_only =True) #1. What does the data tell you. Mean of data.
rtempb
# Out:
# DO2010    8.102174
# DO2011    7.478472
# DO2012    8.566225
# dtype: float64

# %%
print "The schools with the highest dropout rates are Peace and Education High School and Banner Academy South High School."
rtempc = rangea.max(skipna=True, numeric_only=True)
rtempc 
#2. Schools with highest dropout rates.
# Out:
# The schools with the highest dropout rates are Peace and Education High School and Banner Academy South High School.
# DO2010    46.8
# DO2011    41.9
# DO2012    52.6
# dtype: float64

# %%
print "Network of schools with the higher dropout rates is Alternative Schools. "
rtempg = data.iloc[9]
#3. Network of schools with highest dropout rates.
# Out:
# Network of schools with the higher dropout rates is Alternative Schools.

# %%
print "The schools with the highest passing rates are Devry High School, Northside Learning High School, and Northside Learning Prep High School."
rtempd = rangea.min(skipna=True, numeric_only=True)
rtempd #4. Schools with highest passing rates.
# Out:
# The schools with the highest passing rates are Devry High School, Northside Learning High School, and Northside Learning Prep High School.
# DO2010    0.0
# DO2011    0.1
# DO2012    0.0
# dtype: float64

# %%
print "The school with the highest passing rate of students is Northside Prep High School."
rtempe = data.iloc[94]
rtempe #5. School with largest passing percentages.
# Out:
# The school with the highest passing rate of students is Northside Learning High School.
# School Name                           NORTHSIDE PREP HS
# Network        North-Northwest Side High School Network
# DO2010                                              0.4
# DO2011                                              0.1
# DO2012                                              0.4
# Name: 94, dtype: object

# %%
print "The school with highest passing students and percentages is Northside Learning High School."
rtempf = data.iloc[93]
rtempf #6. School with passing percentage and high pass students.
# Out:
# The school with highest passing students and percentages is Northside Learning High School.
# School Name                       NORTHSIDE LEARNING HS
# Network        North-Northwest Side High School Network
# DO2010                                                1
# DO2011                                                1
# DO2012                                                0
# Name: 93, dtype: object
